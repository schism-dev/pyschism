# %% [markdown]
# # PySCHISM example_1.py
# ### Example file for basic model deployment.
# ---

# %%
from pyschism.mesh import Hgrid

# %%
hgrid = Hgrid.open('../../../NOAA_project/hgrid_atlantic.grd', crs='epsg:4326')

# %%
# %matplotlib inline
hgrid.make_plot(show=True)
# Out:
# <AxesSubplot:>
